# %%
from wa_infra_tools.database.PostgresDatabase import PostgresDatabase
db = PostgresDatabase("sbradin", hostname = "tux-144.cae.wisc.edu")
# Out:
# Password: Duo two-factor login for sbradin
#
# Enter a passcode or select one of the following options:
#
#  1. Duo Push to XXX-XXX-0483
#
# Passcode or option (1-1): Connecting to host='localhost' port='1234' dbname='wa' user='wa_admin' password='wa'
# Connected! Tunnel open ('127.0.0.1', 49842) -> ('144.92.242.141', 22) -> ('localhost', 5432)

# %%
print(db.get_schema("bb_labels"))
db.sql("select dataset from bb_labels")
# Out:
# [('label_id', 'integer', None), ('class_id', 'integer', None), ('class', 'character varying', 128), ('center_norm_x', 'real', None), ('center_norm_y', 'real', None), ('height_norm', 'real', None), ('width_norm', 'real', None), ('image_id', 'integer', None), ('dataset', 'character varying', 128)]
# [('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('bdd100k',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ('nuimages',),
#  ...]
# Tunnel closed from ('127.0.0.1', 49842)
